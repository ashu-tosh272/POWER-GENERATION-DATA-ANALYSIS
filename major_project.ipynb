# %% [markdown]
# <a href="https://colab.research.google.com/github/ashu-tosh272/POWER-GENERATION-DATA-ANALYSIS/blob/main/major_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA SET -01

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1=pd.read_csv("Daily_Power_Gen_Source_march_23.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1.head()
# Out:
#          source     NR     WR     SR     ER   NER  All India        date
# 0         Hydro  139.0   43.0   72.0   30.0   7.0        292  2013-03-31
# 1         Total  675.0  820.0  697.0  306.0  28.0       2526  2013-03-31
# 2  Wind Gen(MU)    2.0   19.0   13.0    0.0   0.0         34  2013-03-31
# 3         Hydro  137.0   43.0   83.0   32.0   5.0        300  2013-04-01
# 4         Total  683.0  841.0  706.0  316.0  29.0       2575  2013-04-01

# %%
#to see numbers of rows and columns
print(df1.shape)
# Out:
# (18251, 8)

# %%
#removing all rows having 'Total' in 'source' column
df1_source= df1.drop(df1[df1['source'] == 'Total'].index)

# %%
df1_source.head()
# Out:
#          source     NR    WR    SR    ER  NER  All India        date
# 0         Hydro  139.0  43.0  72.0  30.0  7.0        292  2013-03-31
# 2  Wind Gen(MU)    2.0  19.0  13.0   0.0  0.0         34  2013-03-31
# 3         Hydro  137.0  43.0  83.0  32.0  5.0        300  2013-04-01
# 5  Wind Gen(MU)    7.0  21.0  19.0   0.0  0.0         48  2013-04-01
# 6  Wind Gen(MU)    8.0  25.0  15.0   0.0  0.0         48  2013-04-02

# %%
print(df1_source.shape)
# Out:
# (14822, 8)

# %%
df1_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14822 entries, 0 to 18249
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source     14822 non-null  object
#  1   NR         14822 non-null  float64
#  2   WR         14822 non-null  float64
#  3   SR         14822 non-null  float64
#  4   ER         14822 non-null  float64
#  5   NER        14822 non-null  float64
#  6   All India  14822 non-null  int64
#  7   date       14822 non-null  object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
df1_source.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        source     NR     WR     SR     ER    NER  All India   date
# 0       False  False  False  False  False  False      False  False
# 2       False  False  False  False  False  False      False  False
# 3       False  False  False  False  False  False      False  False
# 5       False  False  False  False  False  False      False  False
# 6       False  False  False  False  False  False      False  False
# ...       ...    ...    ...    ...    ...    ...        ...    ...
# 18245   False  False  False  False  False  False      False  False
# 18246   False  False  False  False  False  False      False  False
# 18247   False  False  False  False  False  False      False  False
# 18248   False  False  False  False  False  False      False  False
# 18249   False  False  False  False  False  False      False  False
#
# [14822 rows x 8 columns]>

# %%
df1_source.head()
# Out:
#          source     NR    WR    SR    ER  NER  All India        date
# 0         Hydro  139.0  43.0  72.0  30.0  7.0        292  2013-03-31
# 2  Wind Gen(MU)    2.0  19.0  13.0   0.0  0.0         34  2013-03-31
# 3         Hydro  137.0  43.0  83.0  32.0  5.0        300  2013-04-01
# 5  Wind Gen(MU)    7.0  21.0  19.0   0.0  0.0         48  2013-04-01
# 6  Wind Gen(MU)    8.0  25.0  15.0   0.0  0.0         48  2013-04-02

# %% [markdown]
# DATA SET 2

# %%
df2=pd.read_csv("Daily_Power_Gen_States_march_23.csv")

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)        date
# 0                                 1.0              1.2  2015-01-01
# 1                                 0.0              4.8  2015-01-01
# 2                                 0.0              7.3  2015-01-01
# 3                                57.0            315.0  2015-01-01
# 4                                 0.0            109.8  2015-01-01

# %%
print(df2.shape)
# Out:
# (126699, 6)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126699 entries, 0 to 126698
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Region                              126699 non-null  object
#  1   States                              126699 non-null  object
#  2   Max.Demand Met during the day(MW)   126699 non-null  int64
#  3   Shortage during maximum Demand(MW)  126680 non-null  float64
#  4   Energy Met (MU)                     126698 non-null  float64
#  5   date                                126699 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.8+ MB

# %%
df2.isnull().sum()
# Out:
# Region                                 0
# States                                 0
# Max.Demand Met during the day(MW)      0
# Shortage during maximum Demand(MW)    19
# Energy Met (MU)                        1
# date                                   0
# dtype: int64

# %%
df2['Shortage during maximum Demand(MW)'] = df2['Shortage during maximum Demand(MW)'].fillna(df2['Shortage during maximum Demand(MW)'].mean())

# %%
df2.isnull().sum()
# Out:
# Region                                0
# States                                0
# Max.Demand Met during the day(MW)     0
# Shortage during maximum Demand(MW)    0
# Energy Met (MU)                       1
# date                                  0
# dtype: int64

# %%
#we have replace null values with mean "Shortage during maximum Demand(MW)" and 0 for "Energy Met (MU)" resp.

# %%
df2.duplicated().any()
# Out:
# False

# %%
#for df2
df2['date'] = pd.to_datetime(df2['date'])

df2['day'] = df2['date'].dt.day
df2['month'] = df2['date'].dt.month
df2['year'] = df2['date'].dt.year

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MU)       date  day  month  \
# 0                                 1.0              1.2 2015-01-01    1      1
# 1                                 0.0              4.8 2015-01-01    1      1
# 2                                 0.0              7.3 2015-01-01    1      1
# 3                                57.0            315.0 2015-01-01    1      1
# 4                                 0.0            109.8 2015-01-01    1      1
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126699 entries, 0 to 126698
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Region                              126699 non-null  object
#  1   States                              126699 non-null  object
#  2   Max.Demand Met during the day(MW)   126699 non-null  int64
#  3   Shortage during maximum Demand(MW)  126699 non-null  float64
#  4   Energy Met (MU)                     126698 non-null  float64
#  5   date                                126699 non-null  datetime64[ns]
#  6   day                                 126699 non-null  int64
#  7   month                               126699 non-null  int64
#  8   year                                126699 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 8.7+ MB

# %%
#df2['Energy Met (MU)']=df2['Energy Met (MU)']*1000
df2.rename(columns={'Energy Met (MU)': 'Energy Met (MW)'}, inplace=True)
df2['Energy Met (MW)']=df2['Energy Met (MW)']*1000

# %%
df2.head()
# Out:
#   Region       States  Max.Demand Met during the day(MW)  \
# 0    NER      Mizoram                                 77
# 1     WR           DD                                214
# 2     WR          Goa                                383
# 3     WR  Maharashtra                              14837
# 4     WR           MP                               5740
#
#    Shortage during maximum Demand(MW)  Energy Met (MW)       date  day  month  \
# 0                                 1.0           1200.0 2015-01-01    1      1
# 1                                 0.0           4800.0 2015-01-01    1      1
# 2                                 0.0           7300.0 2015-01-01    1      1
# 3                                57.0         315000.0 2015-01-01    1      1
# 4                                 0.0         109800.0 2015-01-01    1      1
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %% [markdown]
# DATA SET 01

# %%
df1_source.describe()
# Out:
#                  NR            WR            SR            ER           NER  \
# count  14822.000000  14822.000000  14822.000000  14822.000000  14822.000000
# mean     144.294559    192.747309    129.275448     77.964625      8.239123
# std      188.317055    385.111533    160.078391    161.101873     10.276652
# min       -2.940000      0.000000      2.000000      0.000000      0.000000
# 25%       23.000000     21.000000     33.000000      0.000000      0.000000
# 50%       43.000000     38.000000     63.000000      1.000000      2.000000
# 75%      176.000000     82.000000    147.000000     51.000000     15.000000
# max      829.000000   1565.000000    745.000000    743.000000     52.000000
#
#           All India
# count  14822.000000
# mean     552.463838
# std      867.984287
# min       13.000000
# 25%       94.000000
# 50%      208.000000
# 75%      453.000000
# max     3695.000000

# %%
df1_source1=df1_source.copy()
print(df1_source1.columns)
# Out:
# Index(['source', 'NR', 'WR', 'SR', 'ER', 'NER', 'All India', 'date'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lineplot(data=df1_source1, x='date', y='All India', hue='source')
plt.title('Power Generation by Source over Time')
plt.xlabel('Date')
plt.ylabel('Power Generation')
plt.show()
df1_source.head()
# Out:
#          source     NR    WR    SR    ER  NER  All India        date
# 0         Hydro  139.0  43.0  72.0  30.0  7.0        292  2013-03-31
# 2  Wind Gen(MU)    2.0  19.0  13.0   0.0  0.0         34  2013-03-31
# 3         Hydro  137.0  43.0  83.0  32.0  5.0        300  2013-04-01
# 5  Wind Gen(MU)    7.0  21.0  19.0   0.0  0.0         48  2013-04-01
# 6  Wind Gen(MU)    8.0  25.0  15.0   0.0  0.0         48  2013-04-02

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df1_source1, y='source', x='All India')
plt.title('Power Generation by Source')
plt.ylabel('Source')
plt.xlabel('Power Generation')
plt.show()

# %%
# Time series analysis
df1_source1['date'] = pd.to_datetime(df1_source1['date'])
df1_source1.set_index('date', inplace=True)
hydro_generation = df1_source1[df1_source1['source'] == 'Hydro']['All India']
plt.figure(figsize=(10, 6))
hydro_generation.plot()
plt.title('Hydro Power Generation over Time')
plt.xlabel('Date')
plt.ylabel('Power Generation')
plt.show()

# %% [markdown]
# Comparison Between Renewable and Non-Renewable Sources of Power Generation

# %%
import warnings

# Ignore warning messages
warnings.filterwarnings("ignore")

df1=pd.read_csv("Daily_Power_Gen_Source_march_23.csv")


df1_source= df1.drop(df1[df1['source'] == 'Total'].index)

res_data = df1_source[df1_source['source'].str.startswith('RES')]
res_data['date'] = res_data['date'].astype(str)
res_data = res_data.groupby(res_data['date'].str.split('-').str[0])['All India'].sum().reset_index()

gas_data = df1_source[df1_source['source'].str.startswith('Gas')]
gas_data['date'] = gas_data['date'].astype(str)
gas_data = gas_data.groupby(gas_data['date'].str.split('-').str[0])['All India'].sum().reset_index()

combined_data = res_data.merge(gas_data, on='date')
combined_data.columns = ['Year', 'Renewable Energy', 'Fossil Fuels']

sns.lineplot(data=combined_data, x='Year', y='Renewable Energy', label='Renewable Energy',color="green")
sns.lineplot(data=combined_data, x='Year', y='Fossil Fuels', label='Fossil Fuels',color="brown")

plt.xlabel('Year')
plt.ylabel('Power Generation')
plt.title('Power Generation Comparison')
plt.legend()

fig = plt.gcf()
fig.set_facecolor('lightgray')

plt.show()

# %% [markdown]
# DISTRIBUTED MAP

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1689579086527' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bo&#47;Book1_16895978252330&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Book1_16895978252330&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bo&#47;Book1_16895978252330&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1689579086527');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1920px';vizElement.style.height='1107px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1920px';vizElement.style.height='1107px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';vizElement.parentNode.insertBefore(scriptElement, vizElement);
# Out:
# <div class='tableauPlaceholder' id='viz1689579086527' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bo&#47;Book1_16895978252330&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Book1_16895978252330&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bo&#47;Book1_16895978252330&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1689579086527');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1920px';vizElement.style.height='1107px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1920px';vizElement.style.height='1107px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';vizElement.parentNode.insertBefore(scriptElement, vizElement);

# %%
# Create a box plot of energy demand by source and region NR
sns.boxplot(x='source', y='NR', data=df1_source)
plt.xlabel('Source')
plt.ylabel('Energy Demand (MW)')
plt.title('Energy Demand by Source and Region NR')
plt.yticks([50,100,150,200,250,300,400,600,800])
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Create a box plot of energy demand by source and region SR
sns.boxplot(x='source', y='SR', data=df1_source)
plt.xlabel('Source')
plt.ylabel('Energy Demand (MW)')
plt.title('Energy Demand by Source and Region SR')
plt.yticks([25,50,100,200,400,600])
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Create a box plot of energy demand by source and region ER
sns.boxplot(x='source', y='ER', data=df1_source)
plt.xlabel('Source')
plt.ylabel('Energy Demand (MW)')
plt.title('Energy Demand by Source and Region ER')
plt.yticks([50,100,150,200,400,600])
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Create a box plot of energy demand by source and region NER
sns.boxplot(x='source', y='NER', data=df1_source)
plt.xlabel('Source')
plt.ylabel('Energy Demand (MW)')
plt.title('Energy Demand by Source and Region NER')
plt.yticks([5,10,15,20,25,30,35,40,45,50])
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df1_source_grouped = df1_source.groupby('source')['All India'].sum()
df1_source_grouped.head()
# Out:
# source
# Coal                    4137214
# Gas, Naptha & Diesel     210227
# Hydro                   1429124
# Lignite                  119809
# Nuclear                  209917
# Name: All India, dtype: int64

# %%
# Plot the pie chart
plt.pie(df1_source_grouped, labels=df1_source_grouped.index, autopct='%1.1f%%')
plt.title('Total Energy production by Source (2013-2023)')
plt.show()

# %%
print(df1_source['source'].unique())
print(df1_source['source'].nunique())
df1_source.head()
# Out:
# ['Hydro' 'Wind Gen(MU)' 'Solar Gen (MU)' 'Nuclear'
#  'Thermal (Coal & Lignite)' 'Gas, Naptha & Diesel'
#  'RES (Wind, Solar, Biomass & Others)' 'Lignite' 'Coal']
# 9
#          source     NR    WR    SR    ER  NER  All India        date
# 0         Hydro  139.0  43.0  72.0  30.0  7.0        292  2013-03-31
# 2  Wind Gen(MU)    2.0  19.0  13.0   0.0  0.0         34  2013-03-31
# 3         Hydro  137.0  43.0  83.0  32.0  5.0        300  2013-04-01
# 5  Wind Gen(MU)    7.0  21.0  19.0   0.0  0.0         48  2013-04-01
# 6  Wind Gen(MU)    8.0  25.0  15.0   0.0  0.0         48  2013-04-02

# %%
df1_source_hydro=df1_source.query('source == "Hydro"')
df1_source_hydro.head()
# Out:
#    source     NR    WR    SR    ER  NER  All India        date
# 0   Hydro  139.0  43.0  72.0  30.0  7.0        292  2013-03-31
# 3   Hydro  137.0  43.0  83.0  32.0  5.0        300  2013-04-01
# 8   Hydro  136.0  42.0  79.0  29.0  4.0        290  2013-04-02
# 10  Hydro  135.0  42.0  80.0  38.0  4.0        299  2013-04-03
# 13  Hydro  133.0  44.0  78.0  38.0  5.0        297  2013-04-04

# %%
df1_source_hydro['date'] = pd.to_datetime(df1_source_hydro['date'])

# %%
df1_source_hydro_grp = df1_source_hydro.groupby(df1_source_hydro['date'].dt.year)['All India'].sum()
df1_source_hydro_grp.head()
# Out:
# date
# 2013    112288
# 2014    136047
# 2015    129344
# 2016    128054
# 2017    132676
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_hydro_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise hydro Energy Demand ')
plt.show()

# %%
df1_source_Wind=df1_source.query('source == "Wind Gen(MU)"')
df1_source_Wind.head()
# Out:
#           source   NR    WR    SR   ER  NER  All India        date
# 2   Wind Gen(MU)  2.0  19.0  13.0  0.0  0.0         34  2013-03-31
# 5   Wind Gen(MU)  7.0  21.0  19.0  0.0  0.0         48  2013-04-01
# 6   Wind Gen(MU)  8.0  25.0  15.0  0.0  0.0         48  2013-04-02
# 11  Wind Gen(MU)  3.0  22.0   6.0  0.0  0.0         31  2013-04-03
# 14  Wind Gen(MU)  3.0  23.0  15.0  0.0  0.0         42  2013-04-04

# %%
df1_source_Wind['date'] = pd.to_datetime(df1_source_Wind['date'])

# %%
df1_source_Wind_grp = df1_source_Wind.groupby(df1_source_Wind['date'].dt.year)['All India'].sum()
df1_source_Wind_grp.head()
# Out:
# date
# 2013    22089
# 2014    27935
# 2015    27856
# 2016    39161
# 2017    36795
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_Wind_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise Wind Energy Demand ')
plt.show()

# %%
df1_source_Solar=df1_source.query('source == "Solar Gen (MU)"')
df1_source_Solar.head()
# Out:
#               source    NR     WR    SR    ER   NER  All India        date
# 2937  Solar Gen (MU)  1.99   9.65  16.0  0.03  0.02         28  2016-01-01
# 3737  Solar Gen (MU)  3.01  10.79   9.4  0.04  0.03         23  2016-09-27
# 3743  Solar Gen (MU)  3.43  10.64   8.4  0.00  0.01         22  2016-09-28
# 3747  Solar Gen (MU)  0.47  11.19   8.5  0.00  0.02         20  2016-09-29
# 3751  Solar Gen (MU)  0.35   9.67   9.4  0.00  0.02         19  2016-09-30

# %%
df1_source_Solar['date'] = pd.to_datetime(df1_source_Solar['date'])

# %%
df1_source_Solar_grp = df1_source_Solar.groupby(df1_source_Solar['date'].dt.year)['All India'].sum()
df1_source_Solar_grp.head()
# Out:
# date
# 2016    2408
# 2017    8278
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_Solar_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise Solar Energy Demand ')
plt.show()

# %%
df1_source_Nuclear=df1_source.query('source == "Nuclear"')
df1_source_Nuclear.head()
# Out:
#        source    NR    WR    SR   ER  NER  All India        date
# 4662  Nuclear  26.0  17.0  40.0  0.0  0.0         84  2017-05-26
# 4945  Nuclear  32.0   2.0  28.0  0.0  0.0         62  2017-08-28
# 4954  Nuclear  32.0   3.0  30.0  0.0  0.0         65  2017-08-29
# 4958  Nuclear  32.0   3.0  35.0  0.0  0.0         70  2017-08-30
# 4967  Nuclear  33.0   3.0  42.0  0.0  0.0         79  2017-08-31

# %%
df1_source_Nuclear['date'] = pd.to_datetime(df1_source_Nuclear['date'])

# %%
df1_source_Nuclear_grp = df1_source_Nuclear.groupby(df1_source_Nuclear['date'].dt.year)['All India'].sum()
df1_source_Nuclear_grp.head()
# Out:
# date
# 2017    12131
# 2018    33283
# 2019    36918
# 2020    34377
# 2021    38268
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_Nuclear_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise Nuclear Energy Demand ')
plt.show()

# %%
df1_source_Thermal=df1_source.query('source == "Thermal (Coal & Lignite)"')
df1_source_Thermal.head()
# Out:
#                         source     NR      WR     SR     ER  NER  All India  \
# 4664  Thermal (Coal & Lignite)  645.0  1232.0  622.0  448.0  9.0       2956
# 4949  Thermal (Coal & Lignite)  536.0  1033.0  452.0  378.0  4.0       2402
# 4950  Thermal (Coal & Lignite)  511.0   950.0  434.0  373.0  4.0       2273
# 4956  Thermal (Coal & Lignite)  515.0   933.0  472.0  381.0  5.0       2304
# 4966  Thermal (Coal & Lignite)  489.0   973.0  544.0  378.0  5.0       2389
#
#             date
# 4664  2017-05-26
# 4949  2017-08-28
# 4950  2017-08-29
# 4956  2017-08-30
# 4966  2017-08-31

# %%
df1_source_Thermal['date'] = pd.to_datetime(df1_source_Thermal['date'])

# %%
df1_source_Thermal_grp = df1_source_Thermal.groupby(df1_source_Thermal['date'].dt.year)['All India'].sum()
df1_source_Thermal_grp.head()
# Out:
# date
# 2017    313624
# 2018    869991
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
plt.bar(df1_source_Thermal_grp.index,df1_source_Thermal_grp)
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise Thermal Energy Demand ')
plt.show()

# %%
df1_source_NDG=df1_source.query('source == "Gas, Naptha & Diesel"')
df1_source_NDG.head()
# Out:
#                     source    NR    WR    SR   ER   NER  All India        date
# 4667  Gas, Naptha & Diesel  37.0  49.0  19.0  0.0  22.0        127  2017-05-26
# 4944  Gas, Naptha & Diesel  39.0  46.0  15.0  0.0  12.0        112  2017-08-28
# 4953  Gas, Naptha & Diesel  44.0  44.0  15.0  0.0  12.0        115  2017-08-29
# 4959  Gas, Naptha & Diesel  36.0  43.0  15.0  0.0  12.0        107  2017-08-30
# 4964  Gas, Naptha & Diesel  38.0  47.0  15.0  0.0  11.0        111  2017-08-31

# %%
df1_source_NDG['date'] = pd.to_datetime(df1_source_NDG['date'])
df1_source_NDG_grp = df1_source_NDG.groupby(df1_source_NDG['date'].dt.year)['All India'].sum()
df1_source_NDG_grp.head()
# Out:
# date
# 2017    17633
# 2018    44628
# 2019    43112
# 2020    42551
# 2021    34195
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_NDG_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise NDG Energy Demand ')
plt.show()

# %%
df1_source_RES=df1_source.query('source == "RES (Wind, Solar, Biomass & Others)"')
df1_source_RES.head()
# Out:
#                                    source    NR     WR     SR   ER  NER  \
# 4668  RES (Wind, Solar, Biomass & Others)  40.0  110.0  111.0  1.0  0.0
# 4948  RES (Wind, Solar, Biomass & Others)  19.0   63.0  219.0  2.0  0.0
# 4952  RES (Wind, Solar, Biomass & Others)  34.0   78.0  225.0  1.0  0.0
# 4960  RES (Wind, Solar, Biomass & Others)  38.0   88.0  205.0  1.0  0.0
# 4963  RES (Wind, Solar, Biomass & Others)  25.0   98.0  133.0  1.0  0.0
#
#       All India        date
# 4668        263  2017-05-26
# 4948        303  2017-08-28
# 4952        339  2017-08-29
# 4960        332  2017-08-30
# 4963        257  2017-08-31

# %%
df1_source_RES['date'] = pd.to_datetime(df1_source_RES['date'])
df1_source_RES_grp = df1_source_RES.groupby(df1_source_RES['date'].dt.year)['All India'].sum()
df1_source_RES_grp.head()
# Out:
# date
# 2017     23460
# 2018    107288
# 2019    122996
# 2020    113554
# 2021    144189
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_RES_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise RES Energy Demand ')
plt.show()

# %%
df1_source_Lignite=df1_source.query('source == "Lignite"')
df1_source_Lignite.head()
# Out:
#        source    NR    WR    SR   ER  NER  All India        date
# 7620  Lignite  23.0  16.0  58.0  0.0  0.0         97  2018-11-29
# 7629  Lignite  24.0  16.0  54.0  0.0  0.0         93  2018-11-30
# 7635  Lignite  23.0  16.0  55.0  0.0  0.0         94  2018-12-01
# 7642  Lignite  21.0  16.0  50.0  0.0  0.0         86  2018-12-02
# 7652  Lignite  21.0  15.0  51.0  0.0  0.0         87  2018-12-03

# %%
df1_source_Lignite['date'] = pd.to_datetime(df1_source_Lignite['date'])
df1_source_Lignite_grp = df1_source_Lignite.groupby(df1_source_Lignite['date'].dt.year)['All India'].sum()
df1_source_Lignite_grp.head()
# Out:
# date
# 2018     2751
# 2019    29075
# 2020    22190
# 2021    25956
# 2022    30519
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_Lignite_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise RES Energy Demand ')
plt.show()

# %%
df1_source_Coal=df1_source.query('source == "Coal"')
df1_source_Coal.head()
# Out:
#      source     NR      WR     SR     ER   NER  All India        date
# 7621   Coal  528.0  1190.0  493.0  409.0  10.0       2631  2018-11-29
# 7627   Coal  531.0  1172.0  496.0  408.0  10.0       2615  2018-11-30
# 7634   Coal  515.0  1183.0  484.0  409.0  10.0       2600  2018-12-01
# 7641   Coal  475.0  1172.0  452.0  406.0   7.0       2511  2018-12-02
# 7653   Coal  503.0  1189.0  476.0  405.0   4.0       2576  2018-12-03

# %%
df1_source_Coal['date'] = pd.to_datetime(df1_source_Coal['date'])
df1_source_Coal_grp = df1_source_Coal.groupby(df1_source_Coal['date'].dt.year)['All India'].sum()
df1_source_Coal_grp.head()
# Out:
# date
# 2018      83042
# 2019     914526
# 2020     771398
# 2021     973322
# 2022    1087498
# Name: All India, dtype: int64

# %%
# Create a line plot of energy demand by source
df1_source_Coal_grp.plot()
plt.xlabel('Year')
plt.ylabel('Total energy produced all over India')
plt.title('yearwise Coal Energy Demand ')
plt.yticks([200000, 400000, 600000, 800000, 1000000])
plt.show()

# %%
print(df1_source.columns)
# Out:
# Index(['source', 'NR', 'WR', 'SR', 'ER', 'NER', 'All India', 'date'], dtype='object')

# %% [markdown]
# Region wise representation of Nation wise Power Distribution In India

# %%
df_grouped = df2.groupby('Region')['Max.Demand Met during the day(MW)'].max()
print(df_grouped)
# Out:
# Region
# ER       9989
# NER      2376
# NR      33137
# SR      18048
# WR     111539
# Name: Max.Demand Met during the day(MW), dtype: int64

# %%
df_grouped = df2.groupby('Region')['Max.Demand Met during the day(MW)'].sum()

# Plot the pie chart
plt.pie(df_grouped, labels=df_grouped.index, autopct='%1.1f%%')
plt.title('Max.Demand Met during the day(MW) by Region')
plt.show()

# %%
df_grouped = df2.groupby('Region')['Shortage during maximum Demand(MW)'].sum()

# Plot the pie chart
plt.pie(df_grouped, labels=df_grouped.index, autopct='%1.1f%%')
plt.title('Shortage during maximum Demand(MW) by Region')
plt.show()

# %% [markdown]
# State wise representation of Nation wise Power Distribution

# %%
print(df2['year'].unique())
# Out:
# [2015 2016 2018 2019 2020 2021 2022 2023 2014 2017 2013]

# %%
print(df2['year'].nunique())
# Out:
# 11

# %%
print(df2['States'].nunique())
# Out:
# 45

# %%
print(df2['States'].unique())
# Out:
# ['Mizoram' 'DD' 'Goa' 'Maharashtra' 'MP' 'Gujarat' 'Chhattisgarh' 'DNH'
#  'Chandigarh' 'HP' 'Uttarakhand' 'UP' 'Delhi' 'Rajasthan' 'Haryana' 'J&K'
#  'Punjab' 'Essar steel' 'Andhra Pradesh' 'Meghalaya' 'Manipur' 'Assam'
#  'Arunachal Pradesh' 'Sikkim' 'West Bengal' 'Odisha' 'Jharkhand' 'DVC'
#  'Bihar' 'Pondy' 'Tamil Nadu' 'Kerala' 'Karnataka' 'Telangana' 'Nagaland'
#  'Tripura' 'J&K(UT) and Ladakh(UT)' 'J&K(UT) & Ladakh(UT)' 'AMNSIL'
#  'Puducherry' 'BALCO' 'DNHDDPDCL' 'J&K(UT) & \nLadakh(UT)' 'J&K(UT) &'
#  'Railways_NR ISTS']

# %%
state_count = df2.groupby('States')['Max.Demand Met during the day(MW)'].count()

# %%
state_max_demand = df2.groupby('States')['Max.Demand Met during the day(MW)'].sum()

state_max_demand = state_max_demand.sort_values(ascending=False)

top_states = state_max_demand.head(10)

plt.bar(top_states.index, top_states.values)
plt.xlabel('States')
plt.ylabel('Max.Demand Met during the year(MW)')
plt.title('Top States with Highest Max.Demand Met during the (MW)')
plt.xticks(rotation=90)
plt.show()

# %%
state_max_demand = df2.groupby('States')['Shortage during maximum Demand(MW)'].sum()

state_max_demand = state_max_demand.sort_values(ascending=False)

top_states = state_max_demand.head(10)

plt.bar(top_states.index, top_states.values)
plt.xlabel('States')
plt.ylabel('Shortage during maximum Demand(MW)')
plt.title('Top States with Shortage during maximum Demand(MW) during year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Regression Model

# %%
# Calculate the correlation matrix
corr_matrix = df2.corr()

# Print the correlation matrix
print(corr_matrix)
# Out:
#                                     Max.Demand Met during the day(MW)  \
# Max.Demand Met during the day(MW)                            1.000000
# Shortage during maximum Demand(MW)                           0.153828
# Energy Met (MW)                                              0.992330
# day                                                          0.001178
# month                                                       -0.015992
# year                                                         0.116664
#
#                                     Shortage during maximum Demand(MW)  \
# Max.Demand Met during the day(MW)                             0.153828
# Shortage during maximum Demand(MW)                            1.000000
# Energy Met (MW)                                               0.168927
# day                                                          -0.001512
# month                                                         0.004433
# year                                                         -0.179303
#
#                                     Energy Met (MW)       day     month  \
# Max.Demand Met during the day(MW)          0.992330  0.001178 -0.015992
# Shortage during maximum Demand(MW)         0.168927 -0.001512  0.004433
# Energy Met (MW)                            1.000000  0.001337 -0.011857
# day                                        0.001337  1.000000  0.008476
# month                                     -0.011857  0.008476  1.000000
# year                                       0.100422 -0.000111 -0.120217
#
#                                         year
# Max.Demand Met during the day(MW)   0.116664
# Shortage during maximum Demand(MW) -0.179303
# Energy Met (MW)                     0.100422
# day                                -0.000111
# month                              -0.120217
# year                                1.000000

# %%
# Plot the heatmap of the correlation matrix
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# scatter plot between X(Max.Demand Met during the day(MW)) and Y(Energy Met (MW))
# X-> Max.Demand Met during the day(MW) -> independent var
# Y -> Energy Met (MW) -> dependent var

plt.scatter(df2['Max.Demand Met during the day(MW)'], df2['Energy Met (MW)'])
plt.xlabel('Max.Demand Met during the day(MW)')
plt.ylabel('Energy Met (MW)')
plt.title('Scatter Plot of Energy Met vs Max.Demand Met')
plt.show()

# %% [markdown]
# Regression line is ->
# quantity_produced(MW) = 20.88*(units met[MW]) + (-861.0183190705575)

# %% [markdown]
# Training data with LinearRegression model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x=df2[["Max.Demand Met during the day(MW)"]]
y=df2["Energy Met (MW)"]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=10)
#random_state ensures x_train wont change upon execution each time
model = LinearRegression()

# %%
df2
# Out:
#        Region             States  Max.Demand Met during the day(MW)  \
# 0         NER            Mizoram                                 77
# 1          WR                 DD                                214
# 2          WR                Goa                                383
# 3          WR        Maharashtra                              14837
# 4          WR                 MP                               5740
# ...       ...                ...                                ...
# 126694     SR             Kerala                               3844
# 126695     SR          Karnataka                              13135
# 126696     SR          Telangana                              13723
# 126697    NER            Tripura                                226
# 126698    NER  Arunachal Pradesh                                141
#
#         Shortage during maximum Demand(MW)  Energy Met (MW)       date  day  \
# 0                                      1.0           1200.0 2015-01-01    1
# 1                                      0.0           4800.0 2015-01-01    1
# 2                                      0.0           7300.0 2015-01-01    1
# 3                                     57.0         315000.0 2015-01-01    1
# 4                                      0.0         109800.0 2015-01-01    1
# ...                                    ...              ...        ...  ...
# 126694                                 0.0          76600.0 2022-12-31   31
# 126695                                 0.0         227700.0 2022-12-31   31
# 126696                                 0.0         232100.0 2022-12-31   31
# 126697                                 0.0           3800.0 2022-12-31   31
# 126698                                 0.0           2600.0 2022-12-31   31
#
#         month  year
# 0           1  2015
# 1           1  2015
# 2           1  2015
# 3           1  2015
# 4           1  2015
# ...       ...   ...
# 126694     12  2022
# 126695     12  2022
# 126696     12  2022
# 126697     12  2022
# 126698     12  2022
#
# [126699 rows x 9 columns]

# %%
df2.replace([np.inf, -np.inf], np.NAN).dropna()
# Out:
#        Region             States  Max.Demand Met during the day(MW)  \
# 0         NER            Mizoram                                 77
# 1          WR                 DD                                214
# 2          WR                Goa                                383
# 3          WR        Maharashtra                              14837
# 4          WR                 MP                               5740
# ...       ...                ...                                ...
# 126694     SR             Kerala                               3844
# 126695     SR          Karnataka                              13135
# 126696     SR          Telangana                              13723
# 126697    NER            Tripura                                226
# 126698    NER  Arunachal Pradesh                                141
#
#         Shortage during maximum Demand(MW)  Energy Met (MW)       date  day  \
# 0                                      1.0           1200.0 2015-01-01    1
# 1                                      0.0           4800.0 2015-01-01    1
# 2                                      0.0           7300.0 2015-01-01    1
# 3                                     57.0         315000.0 2015-01-01    1
# 4                                      0.0         109800.0 2015-01-01    1
# ...                                    ...              ...        ...  ...
# 126694                                 0.0          76600.0 2022-12-31   31
# 126695                                 0.0         227700.0 2022-12-31   31
# 126696                                 0.0         232100.0 2022-12-31   31
# 126697                                 0.0           3800.0 2022-12-31   31
# 126698                                 0.0           2600.0 2022-12-31   31
#
#         month  year
# 0           1  2015
# 1           1  2015
# 2           1  2015
# 3           1  2015
# 4           1  2015
# ...       ...   ...
# 126694     12  2022
# 126695     12  2022
# 126696     12  2022
# 126697     12  2022
# 126698     12  2022
#
# [126698 rows x 9 columns]

# %%
df2=df2.replace([np.inf, -np.inf], np.NaN).dropna()

# %%
x_train = df2[["Max.Demand Met during the day(MW)"]]
y_train = df2["Energy Met (MW)"]

lr = LinearRegression()
lr.fit(x_train, y_train)  # Fit the model to the training data

plt.plot(x_train, lr.predict(x_train), color='red')

# Add axis labels and a title
plt.xlabel('Units required and met')
plt.ylabel('Quantity produced')
plt.title('Linear Regression')

# Show the plot
plt.show()

# %%
print("c =", lr.intercept_)
print("m =", lr.coef_)
#y(quantity_produced) = 20.8756 *(units required and met) + -861.0183190705575
# Out:
# c = -861.6361671223567
# m = [20.87626019]

# %% [markdown]
# Regression line is :-
# quantity_produced(MW) = 20.88*(units met[MW]) + (-861.0183190705575)

# %%
# train the model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predicting values for x_test
model.predict(x_test)
# Out:
# array([ 25066.67899467,   1664.39131643, 293368.37501668, ...,
#          1560.01001546, 146107.23560342,  77111.19566   ])

# %%
# compare the values obtained above from y_test
y_test
# Out:
# 77414      24400.0
# 54757       2200.0
# 846       303600.0
# 34164     224400.0
# 7203      126900.0
#             ...
# 6179        6600.0
# 113473    388700.0
# 46624       2000.0
# 81781     135800.0
# 28653      75500.0
# Name: Energy Met (MW), Length: 38010, dtype: float64

# %%
#see the accuracy-> compare x_test and y_test values
model.score(x_test,y_test)
# Out:
# 0.9792894593897667

# %% [markdown]
# TIME SERIES ANALYSIS

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error as mse
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.api import SimpleExpSmoothing, Holt

# %%
series = df1['NR']
result = seasonal_decompose(series, model='additive',period=12)
result.plot()
plt.show()

# %%
#Centered Moving Average
y = df1['NR']
fcast = y.rolling(3,center=True).mean()
plt.plot(y, label='Data',color='blue')
plt.plot(fcast, label='Moving Average Forecast',
         color='red')
plt.legend(loc='best')
plt.show()

y_train = df1['NR'][:-12]
y_test = df1['NR'][-12:]
plt.plot(y_train, label='Train',color='blue')
plt.plot(y_test, label='Test',color='orange')
plt.legend(loc='best')
plt.show()

# %%
#### Trailing Rolling Mean
fcast = y_train.rolling(5,center=False).mean()
lastMA = fcast.iloc[-1]
fSeries = pd.Series(lastMA.repeat(len(y_test)))
MA_fcast = pd.concat([fcast, fSeries],
                     ignore_index=True)
plt.plot(y_train, label='Train',color='blue')
plt.plot(MA_fcast, label='Moving Average Forecast',
         color='red')
plt.plot(y_test, label="Test")
plt.legend(loc='best')
plt.show()

print("MSE =",mse(y_test, fSeries))
# Out:
# MSE = 164300.59333333338

# %%
# Holt's Linear Method
alpha = 0.8
beta = 0.02
### Linear Trend
fit1 = Holt(y_train).fit(smoothing_level=alpha,
                         smoothing_trend=beta)
fcast1 = fit1.forecast(len(y_test))

# plot
y_train.plot(color="blue", label='Train')
y_test.plot(color="pink", label='Test')
fcast1.plot(color="purple", label='Forecast')
plt.text(100,600,"MSE="+str(round(mse(y_test, fcast1),2)))
plt.title("Holt's Linear Trend")
plt.legend(loc='best')
plt.show()

print("MSE =",mse(y_test, fcast1))
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# MSE = 170920.26879819995

# %%
### Additive Damped Trend
alpha = 0.8
beta = 0.02
phi = 0.4
fit3 = Holt(y_train, damped_trend=True).fit(smoothing_level=alpha,
                                      damping_trend= phi,
                                      smoothing_trend=beta)
fcast3 = fit3.forecast(len(y_test))

# plot
y_train.plot(color="blue", label='Train')
y_test.plot(color="pink", label='Test')
fcast3.plot(color="purple", label='Forecast')
plt.text(100,600,"MSE="+str(round(mse(y_test, fcast1),2)))
plt.title("Holt's Additive Damped Trend")
plt.legend(loc='best')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
